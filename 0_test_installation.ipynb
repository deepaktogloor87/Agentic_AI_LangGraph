# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict

# %% [markdown]
# ### BMI_CALCULATOR WORKFLOW

# %% [markdown]
# #### Step 1 : Define State

# %%
class BMIState(TypedDict):
    weight_kg : float
    height_m : float
    bmi : float

# %% [markdown]
# #### Step 2: Define your Graph

# %%
graph = StateGraph(BMIState)

# %%
def calculate_bmi(state: BMIState) -> BMIState:
    weight = state['weight_kg']
    height = state['height_m']

    bmi = weight / (height**2)
    state['bmi'] = round(bmi, 2)

    return state

# %% [markdown]
# #### Step 3: Define Your Nodes

# %%
graph.add_node('calculate_bmi', calculate_bmi)

# %% [markdown]
# #### Step 4: Add edges to your graph

# %%
graph.add_edge(START, 'calculate_bmi')
graph.add_edge('calculate_bmi', END)

# %% [markdown]
# #### Step 5: Compile the Graph

# %%
workflow = graph.compile()

# %% [markdown]
# #### Step 6: Execute Graph

# %%
initial_state = {'weight_kg':80, 'height_m':1.73}
final_state = workflow.invoke(initial_state)
print(final_state)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 2
#       1 initial_state = {'weight_kg':80, 'height_m':1.73}
# ----> 2 final_state = workflow.invoke(initial_state)
#       3 print(final_state)
#
# File c:\Users\Yuvika\Desktop\Agentic_AI_LangGraph\.venv\Lib\site-packages\langgraph\pregel\main.py:3309, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, version, **kwargs)
#    3306             chunks.append(chunk)
#    3307 else:
#    3308     # v1: collect interrupts from updates stream
# -> 3309     for chunk in self.stream(
#    3310         input,
#    3311         config,
#    3312         context=context,
#    3313         stream_mode=(
#    3314             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3315         ),
#    3316         print_mode=print_mode,
#    3317         output_keys=output_keys,
#    3318         interrupt_before=interrupt_before,
#    3319         interrupt_after=interrupt_after,
#    3320         durability=durability,
#    3321         **kwargs,
#    3322     ):
#    3323         if stream_mode == "values":
#    3324             if len(chunk) == 2:
#
# File c:\Users\Yuvika\Desktop\Agentic_AI_LangGraph\.venv\Lib\site-packages\langgraph\pregel\main.py:2736, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, version, **kwargs)
#    2734 for task in loop.match_cached_writes():
#    2735     loop.output_writes(task.id, task.writes, cached=True)
# -> 2736 for _ in runner.tick(
#    2737     [t for t in loop.tasks.values() if not t.writes],
#    2738     timeout=self.step_timeout,
#    2739     get_waiter=get_waiter,
#    2740     schedule_task=loop.accept_push,
#    2741 ):
#    2742     # emit output
#    2743     yield from _output(
#    2744         stream_mode,
#    2745         print_mode,
#    (...)   2751         _state_mapper,
#    2752     )
#    2753 loop.after_tick()
#
# File c:\Users\Yuvika\Desktop\Agentic_AI_LangGraph\.venv\Lib\site-packages\langgraph\pregel\_runner.py:167, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     165 t = tasks[0]
#     166 try:
# --> 167     run_with_retry(
#     168         t,
#     169         retry_policy,
#     170         configurable={
#     171             CONFIG_KEY_CALL: partial(
#     172                 _call,
#     173                 weakref.ref(t),
#     174                 retry_policy=retry_policy,
#     175                 futures=weakref.ref(futures),
#     176                 schedule_task=schedule_task,
#     177                 submit=self.submit,
#     178             ),
#     179         },
#     180     )
#     181     self.commit(t, None)
#     182 except Exception as exc:
#
# File c:\Users\Yuvika\Desktop\Agentic_AI_LangGraph\.venv\Lib\site-packages\langgraph\pregel\_retry.py:96, in run_with_retry(task, retry_policy, configurable)
#      94     task.writes.clear()
#      95     # run the task
# ---> 96     return task.proc.invoke(task.input, config)
#      97 except ParentCommand as exc:
#      98     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File c:\Users\Yuvika\Desktop\Agentic_AI_LangGraph\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:656, in RunnableSeq.invoke(self, input, config, **kwargs)
#     654     # run in context
#     655     with set_config_context(config, run) as context:
# --> 656         input = context.run(step.invoke, input, config, **kwargs)
#     657 else:
#     658     input = step.invoke(input, config)
#
# File c:\Users\Yuvika\Desktop\Agentic_AI_LangGraph\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:400, in RunnableCallable.invoke(self, input, config, **kwargs)
#     398         run_manager.on_chain_end(ret)
#     399 else:
# --> 400     ret = self.func(*args, **kwargs)
#     401 if self.recurse and isinstance(ret, Runnable):
#     402     return ret.invoke(input, config)
#
# Cell In[51], line 3, in calculate_bmi(state)
#       1 def calculate_bmi(state: BMIState) -> BMIState:
#       2     weight = state['weight_kg']
# ----> 3     height = state['height']
#       4
#       5     bmi = weight / (height**2)
#       6     state['bmi'] = round(bmi, 2)
#
# KeyError: 'height'
# During task with name 'calculate_bmi' and id '4d945a22-a642-27f5-5bea-b442c3dcb9bc'
